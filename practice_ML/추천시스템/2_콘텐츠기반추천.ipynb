# %% [markdown]
# ### 1. 아이템(콘텐츠) 속성 분석

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

data = {
    "아이템": ["기생충", "부산행", "태극기", "도둑들", "설국열차", "범죄도시", "쇼생크"],
    "설명": [
        "가난한 가족이 부잣집 집에 몰래 들어가서 기생하는 스토리",
        "좀비 바이러스가 터진 세상에서 부산에 가는 열차 이야기",
        "전쟁에서 싸우는 형제의 이야기",
        "사기를 치고 도둑질하는 도둑들의 이야기",
        "꼬리칸에서 일등칸으로 가는 이야기",
        "조선족 참교육 이야기",
        "15년간 갇혀있던 감옥을 탈출하는 이야기"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#     아이템                               설명
# 0   기생충  가난한 가족이 부잣집 집에 몰래 들어가서 기생하는 스토리
# 1   부산행   좀비 바이러스가 터진 세상에서 부산에 가는 열차 이야기
# 2   태극기                 전쟁에서 싸우는 형제의 이야기
# 3   도둑들            사기를 치고 도둑질하는 도둑들의 이야기
# 4  설국열차               꼬리칸에서 일등칸으로 가는 이야기
# 5  범죄도시                      조선족 참교육 이야기
# 6   쇼생크           15년간 갇혀있던 감옥을 탈출하는 이야기

# %%
import numpy as np
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(df['설명'])
print(pd.DataFrame(tfidf_matrix.toarray()).loc[:, :25])

# 코사인 유사도 계산해보기
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
cosine_df = pd.DataFrame(cosine_sim, index=df["아이템"], columns=df["아이템"])
cosine_df
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.000000  0.353553  0.000000  0.353553  0.000000  0.000000  0.353553
# 1  0.000000  0.000000  0.315673  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.486214  0.000000  0.000000  0.000000  0.000000
# 5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6  0.486467  0.000000  0.000000  0.000000  0.486467  0.486467  0.000000
#
#          7         8         9   ...        16        17        18        19  \
# 0  0.000000  0.000000  0.000000  ...  0.000000  0.353553  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  ...  0.380289  0.000000  0.000000  0.380289
# 2  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.556791  0.000000
# 3  0.000000  0.486467  0.486467  ...  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df['장르'] = np.array([1, 2, 3, 4, 5, 2, 6])
df
# Out:
#     아이템                               설명  장르
# 0   기생충  가난한 가족이 부잣집 집에 몰래 들어가서 기생하는 스토리   1
# 1   부산행   좀비 바이러스가 터진 세상에서 부산에 가는 열차 이야기   2
# 2   태극기                 전쟁에서 싸우는 형제의 이야기   3
# 3   도둑들            사기를 치고 도둑질하는 도둑들의 이야기   4
# 4  설국열차               꼬리칸에서 일등칸으로 가는 이야기   5
# 5  범죄도시                      조선족 참교육 이야기   2
# 6   쇼생크           15년간 갇혀있던 감옥을 탈출하는 이야기   6
