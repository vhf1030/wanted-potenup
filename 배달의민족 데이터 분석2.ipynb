# %% [markdown]
# # 배달의 민족 댓글 데이터 분석
# 제출일: 24/12/16
# 제출파일: 주피터노트북 또는 보고서 파일
# 제출경로: 구글 드라이브 > 프로젝트 > 12월 미니 프로젝트 > 각자 조 폴더
# 각자 제출
#
# ### 요구사항
# - score를 기준으로 댓글의 긍정 / 부정 분류
#     - 긍정: 4~5
#     - 긍정2: 4~5 및 "불편"이라는 단어를 포함하지 않는 리뷰
#     - 부정: 1~3
#     - 댓글의 긍정 / 부정에 대한 분석 진행
# - 데이터 불러오기
# - 댓글의 긍정 / 부정을 나타내는 reaction열 만들기
# - reaction 컬럼 bar 그래프 그리기
# - 형태소 분석기를 사용해서 긍정 / 부정별 워드 클라우드 그리기
# - 긍정 / 부정별 장바구니 분석 및 네트워크 그림 그리기
# - 댓글별 유사도 계산해보고 해석해보기

# %%
import pandas as pd
from matplotlib import pyplot as plt
import koreanize_matplotlib
import seaborn as sns

# %% [markdown]
# ### 데이터 불러오기

# %%
## todo: 빈도수 분석, 네트워크 분석, 댓글별 유사도 분석

reviews = pd.read_csv('data/배달의민족댓글2.csv', index_col=0, encoding="utf8")
print(reviews.head())
print(reviews.shape)
# Out:
#                                                 text  score
# 0                                                NaN      4
# 1                                                NaN      5
# 2                                                NaN      1
# 3  배달의민족 주문시 리뷰를 자주 참고하는 편입니다. 한가지 건의사항이 있다면 최신순,...      4
# 4  내가 주문했던 과거목록에서도 검색기능이 있었으면 좋겠어요.. 분명 이 가게에 시킨 ...      5
# (1003, 2)

# %% [markdown]
# ### 데이터 전처리

# %%
reviews.dropna(inplace=True)
reviews.reset_index(drop=True, inplace=True)
reviews.head()
# Out:
#                                                 text  score
# 0  배달의민족 주문시 리뷰를 자주 참고하는 편입니다. 한가지 건의사항이 있다면 최신순,...      4
# 1  내가 주문했던 과거목록에서도 검색기능이 있었으면 좋겠어요.. 분명 이 가게에 시킨 ...      5
# 2  검색 화면에서 전체/배달/포장 탭 중 배달 탭을 스크롤 내리면서 볼 때, 아래로 스...      1
# 3  배달팁 낮은 순으로 정렬하면 0~4000원 이런식으로 된 가게가 가장 위로 올라옵니...      2
# 4  최근 업데이트가 안드로이드5사양 정도에서는 안되는것 같습니다.. 배민 어플 실행시 ...      3

# %%
import re

# reviews['댓글'] = reviews['댓글'].map(lambda x: x.encode('cp949', 'ignore').decode('cp949'))  # 댓글 이모지 제거
# reviews['review'] = reviews['댓글'].map(lambda x: re.sub("[^가-힣\\s+\\d+]", "", x))
reviews['review'] = reviews['text'].map(lambda x: re.sub("[^\\w\\s]", " ", x))
reviews['review'] = reviews['review'].map(lambda x: re.sub("\\s+", " ", x))  # 1개 이상 반복되는 공백을 1개의 공백으로 치환
reviews['s_len_ori'] = reviews['text'].map(lambda x: len(str(x)))  # 원본 리뷰 글자 수 컬럼 추가
reviews['s_len'] = reviews['review'].map(lambda x: len(str(x)))  # 리뷰 글자 수 컬럼 추가
reviews['reaction'] = "N"
reviews.loc[reviews['score'] >= 4, 'reaction'] = "P"

reviews.head()
# Out:
#                                                 text  score  \
# 0  배달의민족 주문시 리뷰를 자주 참고하는 편입니다. 한가지 건의사항이 있다면 최신순,...      4
# 1  내가 주문했던 과거목록에서도 검색기능이 있었으면 좋겠어요.. 분명 이 가게에 시킨 ...      5
# 2  검색 화면에서 전체/배달/포장 탭 중 배달 탭을 스크롤 내리면서 볼 때, 아래로 스...      1
# 3  배달팁 낮은 순으로 정렬하면 0~4000원 이런식으로 된 가게가 가장 위로 올라옵니...      2
# 4  최근 업데이트가 안드로이드5사양 정도에서는 안되는것 같습니다.. 배민 어플 실행시 ...      3
#
#                                               review  s_len_ori  s_len  \
# 0  배달의민족 주문시 리뷰를 자주 참고하는 편입니다 한가지 건의사항이 있다면 최신순 별...        227    223
# 1  내가 주문했던 과거목록에서도 검색기능이 있었으면 좋겠어요 분명 이 가게에 시킨 기억...        175    168
# 2  검색 화면에서 전체 배달 포장 탭 중 배달 탭을 스크롤 내리면서 볼 때 아래로 스크...        229    224
# 3  배달팁 낮은 순으로 정렬하면 0 4000원 이런식으로 된 가게가 가장 위로 올라옵니...        196    190
# 4  최근 업데이트가 안드로이드5사양 정도에서는 안되는것 같습니다 배민 어플 실행시 업데...        250    244
#
#   reaction
# 0        P
# 1        P
# 2        N
# 3        N
# 4        N

# %% [markdown]
# ### 탐색적 데이터 분석

# %%
# 점수 분포 확인
score_count = reviews.groupby("score").count()["text"]
sns.barplot(score_count)
plt.show()

# 긍정 / 부정 분포 확인
score_count = reviews.groupby("reaction").count()["text"]
sns.barplot(score_count)
plt.show()

# %%
from konlpy.tag import Kkma

kkma = Kkma()

# 리뷰 명사 추출
reviews['nouns'] = reviews['review'].apply(lambda x: kkma.nouns(x))
reviews.head()
# Out:
#                                                 text  score  \
# 0  배달의민족 주문시 리뷰를 자주 참고하는 편입니다. 한가지 건의사항이 있다면 최신순,...      4
# 1  내가 주문했던 과거목록에서도 검색기능이 있었으면 좋겠어요.. 분명 이 가게에 시킨 ...      5
# 2  검색 화면에서 전체/배달/포장 탭 중 배달 탭을 스크롤 내리면서 볼 때, 아래로 스...      1
# 3  배달팁 낮은 순으로 정렬하면 0~4000원 이런식으로 된 가게가 가장 위로 올라옵니...      2
# 4  최근 업데이트가 안드로이드5사양 정도에서는 안되는것 같습니다.. 배민 어플 실행시 ...      3
#
#                                               review  s_len_ori  s_len  \
# 0  배달의민족 주문시 리뷰를 자주 참고하는 편입니다 한가지 건의사항이 있다면 최신순 별...        227    223
# 1  내가 주문했던 과거목록에서도 검색기능이 있었으면 좋겠어요 분명 이 가게에 시킨 기억...        175    168
# 2  검색 화면에서 전체 배달 포장 탭 중 배달 탭을 스크롤 내리면서 볼 때 아래로 스크...        229    224
# 3  배달팁 낮은 순으로 정렬하면 0 4000원 이런식으로 된 가게가 가장 위로 올라옵니...        196    190
# 4  최근 업데이트가 안드로이드5사양 정도에서는 안되는것 같습니다 배민 어플 실행시 업데...        250    244
#
#   reaction                                              nouns
# 0        P  [배달, 민족, 주문, 주문시, 시, 리뷰, 편, 가지, 건의, 건의사항, 사항, ...
# 1        P  [내가, 주문, 과거, 과거목록, 목록, 검색, 검색기능, 기능, 분, 분명, 명,...
# 2        N  [검색, 화면, 전체, 배달, 포장, 탭, 중, 스크롤, 때, 아래, 왼쪽, 오른쪽...
# 3        N  [배달, 배달팁, 팁, 낮, 순, 정렬, 0, 4000, 4000원, 원, 식, 가...
# 4        N  [최근, 업데이트, 드로, 드로이드5사, 이드, 5, 사, 정도, 배, 배민, 민,...

# %%
from collections import Counter
import pprint

# 전체 단어 워드크라우드 시각화
word_list = sum(list(reviews["nouns"]), [])
print(word_list)
counter = Counter(word_list)
counter_mc = dict(counter.most_common(30))
pprint.pp(counter_mc)
# Out:
# ['배달', '민족', '주문', '주문시', '시', '리뷰', '편', '가지', '건의', '건의사항', '사항', '최신', '최신순', '순', '별', '별점순', '점', '뿐', '제가', '메뉴', '특정', '확인', '수', '기능', '메뉴검색', '검색', '검색기능', '필요', '주', '주문수', '문수', '드래그', '시간', '소요', '비효율', '발생', '긍정적', '검토', '주심', '내가', '주문', '과거', '과거목록', '목록', '검색', '검색기능', '기능', '분', '분명', '명', '가게', '기억', '무엇', '메뉴', '검색가능', '가능', '예', '곱창', '을', '곱창목록', '리뷰', '리뷰창', '창', '뷰', '뷰보기', '보기', '거', '검색', '화면', '전체', '배달', '포장', '탭', '중', '스크롤', '때', '아래', '왼쪽', '오른쪽', '불편', '후', '마트', '뭐', '하나', '선택', '좌우', '건', '안', '번', '배달', '배달팁', '팁', '낮', '순', '정렬', '0', '4000', '4000원', '원', '식', '가게', '위', '지역', '추가', '별도', '체크', '결국', '5000', '5000원', '10', '10만원', '만', '이상', '0원', '데', '장난', '하나하나', '가격', '가격대별', '대별', '금액', '확인', '최근', '업데이트', '드로', '드로이드5사', '이드', '5', '사', '정도', '배', '배민', '민', '플', '실행', '실행시', '시', '하라', '업', '데이트', '진행', '열기', '무한', '무한반복', '반복', '수', '삭제', '설치', '환경', '환경설정등', '설정', '등', '증상', '분', '도', '글', '이번', '관련', '파일', '확인', '필요', '참고', '사양', '폰', '거', '핸드폰', '문제', '찜', '찜매장', '매장', '구분', '언제쯤', '개선', '독점', '해이', '건', '건가요', '가요', '유명', '앱', '결제', '관련', '부분', '고', '구성', '단순', '배', '배민페', '민', '페', '사용', '사용절차', '절차', '식', '양식', '중식', '카페', '업종별', '라도', '주세', 'ㄱ', 'ㄷ', 'ㄷ순', '순', '개', '이름', '수', '재', '재검색', '검색', '주문', '목록', '앱', '실행', '실행시', '시', '로그', '로그인', '인', '여부', '비', '비회원', '회원', '이용', '선택', '경우', '나중', '입력', '후', '주문', '결제', '주소', '설정', '순서', '변경', '필요', '때', '어플', '설치', '삭제', '편', '사용', '회원정보', '정보', '저장', '플', '불편', '불편해', '해', 'ㅜ', '처음', '시간', '추가', '저', '사람', '상태', '이유', '수정', '사항', '정도', '거', '사용자', '의견', '음식', '음식배달', '배달', '후', '시간', '리', '리뷰', '뷰', '요청', '상단', '적기', '적기위', '위', '앱', '아무것', '실행', '예', '예전', '전', '랬', '데', '버그', '주세', '답변', '추가', '내용', '알', '핸드폰', '터치', '구동', '창만', '작성', '나', '정상적', '데', '식사', '한번', '최소', '15000', '15000원', '원', '이상', '주문', '거기', '배달', '3000', '3000기본', '기본', '누', '배', '배민의', '민의', '수수료', '장사', '도', '가게', '음식', '자체', '값', '배달팁', '팁', '책정', '수', '수십', '수십번', '번', '점', '개선', '곳', '후', '만족', '차단', '수', '옵션', '거', '자', '자주', '주', '추천', '잠시', '불만족', '때', '차단옵션', '해', '다음', '업데이트', '안녕', '배', '배민', '민', '이용', '사용자', '가지', '건의', '건의사항', '사항', '지지', '리뷰', '별', '별점', '점', '대신', '재', '재방문', '방문', '수', '표시', '옆', '생각', '곳', '그곳', '감사', '결제', '수단', '현장', '없애버렸네', '코로나', '때문', '대면', '권장', '건', '이제', '마스크', '착용', '필수', '추세', '배', '배민1', '민', '1', '제한', '거', 'ㅠ', '예전', '배달', '플', '중', '사용', '지역', '배달', '배달팁', '팁', '가격', '거리', '건', '이해', '책정', '책정방법', '방법', '불만', '집', '자체', '위치', '자동', '메뉴판', '동네', '기입', '고객', '방식', '운영', '부분', '통일', '둘', '둘중', '중', '하나', '신경', '가격대', '대', '고객입장', '입장', '음식', '중심', '거지', '가게', '차이', '나', '거기', '추가', '추가금액', '금액', '손해', '거', '주목', '점주', '각오', '전화', '불편', '개선', '이번', '이번업데이트', '업데이트', '리', '리뷰자', '뷰', '자', '평균', '리뷰', '거', '개선', '검색', '때', '카테고리', '만약', '치즈', '햄버거', '치즈메뉴', '메뉴', '피자', '치킨', '떡볶이', '떡볶이등등', '등등', '분류', '찜', '카테고리별', '별', '찜', '수', '지금', '찜목록', '목록', '수정', '위', '위아래', '아래', '순서', '변경', '저', '하면서', '순', '개인적', '목록정리중', '정리', '중', '오랜만', '배달', '화면', '쿠폰', '광고', '몸', '거', '화딱지', '나', '앱', '건', '치킨', '치킨플러스', '플러스', '호', '호치킨', '브랜드', '브랜드관', '관', '주문', '5000', '5000원', '원', '할인', '와중', '옆', '다운로드', '버튼', '디자인', '디자인때문', '때문', '클릭', '번', '가맹점', '전화', '문제', '본사', '업데이트', '광고효과', '효과', '문', '문제죠', '제죠', '정', '요기', '별', '별점', '점', '문어발', '문어발사업', '사업', '근본', '말', '폰트', '폰트팔', '팔', '남', '민폐', '민폐주지', '주지', '사기', '포함', '정도', '예', '노트', '노트20울트라', '20', '울트라', '사용', '사용중', '중', '배', '배민', '민', '폰', '폰화면', '화면', '전체', '제', '제폰', '간편', '간편알', '알', '설정', '다른앱들', '와도', '줄', '림', '배민만', '민만', '광고', '광고등', '등', '시', '개선', '주실', '완벽', '서비스', '수수료', '배민', '배민1', '1', '노', '노쓸모', '쓸모', '배달', '주소', '주소확인', '확인', '상담', '상담전화', '전화', '때', '통화량', '많으', '시스템', '의도', '조금', '대기', '대기량', '량', '건', '건가요', '가요', '연결', '하다', '이후', '상담항목', '항목', '배', '배민1상', '민', '상', '담', '도달', '한참', '한참대기', '나중', '끊킴', '상담자체', '자체', '피드백', '직원', '가지', '개선', 'ㄴ', '리', '리뷰', '뷰', '더하기', '더하기쿠폰', '쿠폰', '추천', '추천메뉴', '메뉴', '배', '너', '자체', '달', '전', '거', '데', '이유', ...
# {'배달': 414,
#  '수': 341,
#  '주문': 340,
#  '거': 246,
#  '가게': 207,
#  '리뷰': 204,
#  '앱': 204,
#  '배': 192,
#  '배민': 190,
#  '사용': 189,
#  '때': 184,
#  '불편': 184,
#  '메뉴': 182,
#  '기능': 164,
#  '1': 148,
#  '민': 138,
#  '음식': 131,
#  '분': 129,
#  '시간': 128,
#  '전화': 119,
#  '결제': 115,
#  '검색': 111,
#  '업데이트': 109,
#  '안': 105,
#  '쿠폰': 105,
#  '점': 104,
#  '2': 103,
#  '개선': 99,
#  '저': 98,
#  '확인': 97}

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(
    font_path="C:/Windows/Fonts/NGULIM.TTF"
).generate_from_frequencies(counter_mc)
plt.imshow(wordcloud)
plt.title("배달의 민족 리뷰 Word Cloud")
plt.axis('off')
plt.show()

# %%
# # 고유명사 제거 테스트
# text_test = "배달의 민족 배달의민족 배달의  민족 배달의 속도가 빠른 민족"
# print(re.sub("배달의\\s*민족", " ", text_test))

# %%
# 단어 전처리
# 고유명사 제거(텍스트 수준), 한글자 제거(명사 수준), 불용어처리(명사 수준)
review_tmp = list(reviews['review'])
print(review_tmp[0])
review_tmp = [re.sub("배달의\\s*민족", " ", r) for r in review_tmp]
print(review_tmp[0])

# nouns_list = [kkma.nouns(r) for r in review_tmp]
# print(nouns_list[0])
stopwords = ["배민"]
nouns_list = []
for r in review_tmp:
    nouns_tmp = kkma.nouns(r)
    nouns_tmp = [n for n in nouns_tmp if len(n) > 1 and n not in stopwords]
    nouns_list.append(nouns_tmp)

reviews['nouns'] = nouns_list
reviews.head()
# Out:
# 배달의민족 주문시 리뷰를 자주 참고하는 편입니다 한가지 건의사항이 있다면 최신순 별점순 뿐만아니라 제가 주문하고자하는 메뉴를 특정해서 그 메뉴의 리뷰만 확인할 수 있는 기능이 있으면 좋을 것 같습니다 메뉴검색 기능처럼 리뷰에서도 특정 메뉴 검색기능이 필요합니다 주문수가 많지않은 메뉴의 리뷰를 보기 위해서 드래그하느라 시간이 많이 소요되는 비효율이 발생합니다 긍정적으로 검토해주심 좋을 것 같습니다
#   주문시 리뷰를 자주 참고하는 편입니다 한가지 건의사항이 있다면 최신순 별점순 뿐만아니라 제가 주문하고자하는 메뉴를 특정해서 그 메뉴의 리뷰만 확인할 수 있는 기능이 있으면 좋을 것 같습니다 메뉴검색 기능처럼 리뷰에서도 특정 메뉴 검색기능이 필요합니다 주문수가 많지않은 메뉴의 리뷰를 보기 위해서 드래그하느라 시간이 많이 소요되는 비효율이 발생합니다 긍정적으로 검토해주심 좋을 것 같습니다
#                                                 text  score  \
# 0  배달의민족 주문시 리뷰를 자주 참고하는 편입니다. 한가지 건의사항이 있다면 최신순,...      4
# 1  내가 주문했던 과거목록에서도 검색기능이 있었으면 좋겠어요.. 분명 이 가게에 시킨 ...      5
# 2  검색 화면에서 전체/배달/포장 탭 중 배달 탭을 스크롤 내리면서 볼 때, 아래로 스...      1
# 3  배달팁 낮은 순으로 정렬하면 0~4000원 이런식으로 된 가게가 가장 위로 올라옵니...      2
# 4  최근 업데이트가 안드로이드5사양 정도에서는 안되는것 같습니다.. 배민 어플 실행시 ...      3
#
#                                               review  s_len_ori  s_len  \
# 0  배달의민족 주문시 리뷰를 자주 참고하는 편입니다 한가지 건의사항이 있다면 최신순 별...        227    223
# 1  내가 주문했던 과거목록에서도 검색기능이 있었으면 좋겠어요 분명 이 가게에 시킨 기억...        175    168
# 2  검색 화면에서 전체 배달 포장 탭 중 배달 탭을 스크롤 내리면서 볼 때 아래로 스크...        229    224
# 3  배달팁 낮은 순으로 정렬하면 0 4000원 이런식으로 된 가게가 가장 위로 올라옵니...        196    190
# 4  최근 업데이트가 안드로이드5사양 정도에서는 안되는것 같습니다 배민 어플 실행시 업데...        250    244
#
#   reaction                                              nouns
# 0        P  [주문, 주문시, 리뷰, 가지, 건의, 건의사항, 사항, 최신, 최신순, 별점순, ...
# 1        P  [내가, 주문, 과거, 과거목록, 목록, 검색, 검색기능, 기능, 분명, 가게, 기...
# 2        N  [검색, 화면, 전체, 배달, 포장, 스크롤, 아래, 왼쪽, 오른쪽, 불편, 마트,...
# 3        N  [배달, 배달팁, 정렬, 4000, 4000원, 가게, 지역, 추가, 별도, 체크,...
# 4        N  [최근, 업데이트, 드로, 드로이드5사, 이드, 정도, 실행, 실행시, 하라, 데이...

# %%
# 전체 단어 워드크라우드 시각화
word_list = sum(list(reviews["nouns"]), [])
print(word_list)
counter = Counter(word_list)
counter_mc = dict(counter.most_common(30))
# pprint.pp(counter_mc)

wordcloud = WordCloud(
    font_path="C:/Windows/Fonts/NGULIM.TTF"
).generate_from_frequencies(counter_mc)
plt.imshow(wordcloud)
plt.title("배달의 민족 리뷰 Word Cloud")
plt.axis('off')
plt.show()
# Out:
# ['주문', '주문시', '리뷰', '가지', '건의', '건의사항', '사항', '최신', '최신순', '별점순', '제가', '메뉴', '특정', '확인', '기능', '메뉴검색', '검색', '검색기능', '필요', '주문수', '문수', '드래그', '시간', '소요', '비효율', '발생', '긍정적', '검토', '주심', '내가', '주문', '과거', '과거목록', '목록', '검색', '검색기능', '기능', '분명', '가게', '기억', '무엇', '메뉴', '검색가능', '가능', '곱창', '곱창목록', '리뷰', '리뷰창', '뷰보기', '보기', '검색', '화면', '전체', '배달', '포장', '스크롤', '아래', '왼쪽', '오른쪽', '불편', '마트', '하나', '선택', '좌우', '배달', '배달팁', '정렬', '4000', '4000원', '가게', '지역', '추가', '별도', '체크', '결국', '5000', '5000원', '10', '10만원', '이상', '0원', '장난', '하나하나', '가격', '가격대별', '대별', '금액', '확인', '최근', '업데이트', '드로', '드로이드5사', '이드', '정도', '실행', '실행시', '하라', '데이트', '진행', '열기', '무한', '무한반복', '반복', '삭제', '설치', '환경', '환경설정등', '설정', '증상', '이번', '관련', '파일', '확인', '필요', '참고', '사양', '핸드폰', '문제', '찜매장', '매장', '구분', '언제쯤', '개선', '독점', '해이', '건가요', '가요', '유명', '결제', '관련', '부분', '구성', '단순', '배민페', '사용', '사용절차', '절차', '양식', '중식', '카페', '업종별', '라도', '주세', 'ㄷ순', '이름', '재검색', '검색', '주문', '목록', '실행', '실행시', '로그', '로그인', '여부', '비회원', '회원', '이용', '선택', '경우', '나중', '입력', '주문', '결제', '주소', '설정', '순서', '변경', '필요', '어플', '설치', '삭제', '사용', '회원정보', '정보', '저장', '불편', '불편해', '처음', '시간', '추가', '사람', '상태', '이유', '수정', '사항', '정도', '사용자', '의견', '음식', '음식배달', '배달', '시간', '리뷰', '요청', '상단', '적기', '적기위', '아무것', '실행', '예전', '버그', '주세', '답변', '추가', '내용', '핸드폰', '터치', '구동', '창만', '작성', '정상적', '식사', '한번', '최소', '15000', '15000원', '이상', '주문', '거기', '배달', '3000', '3000기본', '기본', '배민의', '민의', '수수료', '장사', '가게', '음식', '자체', '배달팁', '책정', '수십', '수십번', '개선', '만족', '차단', '옵션', '자주', '추천', '잠시', '불만족', '차단옵션', '다음', '업데이트', '안녕', '이용', '사용자', '가지', '건의', '건의사항', '사항', '지지', '리뷰', '별점', '대신', '재방문', '방문', '표시', '생각', '그곳', '감사', '결제', '수단', '현장', '없애버렸네', '코로나', '때문', '대면', '권장', '이제', '마스크', '착용', '필수', '추세', '배민1', '제한', '예전', '배달', '사용', '지역', '배달', '배달팁', '가격', '거리', '이해', '책정', '책정방법', '방법', '불만', '자체', '위치', '자동', '메뉴판', '동네', '기입', '고객', '방식', '운영', '부분', '통일', '둘중', '하나', '신경', '가격대', '고객입장', '입장', '음식', '중심', '거지', '가게', '차이', '거기', '추가', '추가금액', '금액', '손해', '주목', '점주', '각오', '전화', '불편', '개선', '이번', '이번업데이트', '업데이트', '리뷰자', '평균', '리뷰', '개선', '검색', '카테고리', '만약', '치즈', '햄버거', '치즈메뉴', '메뉴', '피자', '치킨', '떡볶이', '떡볶이등등', '등등', '분류', '카테고리별', '지금', '찜목록', '목록', '수정', '위아래', '아래', '순서', '변경', '하면서', '개인적', '목록정리중', '정리', '오랜만', '배달', '화면', '쿠폰', '광고', '화딱지', '치킨', '치킨플러스', '플러스', '호치킨', '브랜드', '브랜드관', '주문', '5000', '5000원', '할인', '와중', '다운로드', '버튼', '디자인', '디자인때문', '때문', '클릭', '가맹점', '전화', '문제', '본사', '업데이트', '광고효과', '효과', '문제죠', '제죠', '요기', '별점', '문어발', '문어발사업', '사업', '근본', '폰트', '폰트팔', '민폐', '민폐주지', '주지', '사기', '포함', '정도', '노트', '노트20울트라', '20', '울트라', '사용', '사용중', '폰화면', '화면', '전체', '제폰', '간편', '간편알', '설정', '다른앱들', '와도', '배민만', '민만', '광고', '광고등', '개선', '주실', '완벽', '서비스', '수수료', '배민1', '노쓸모', '쓸모', '배달', '주소', '주소확인', '확인', '상담', '상담전화', '전화', '통화량', '많으', '시스템', '의도', '조금', '대기', '대기량', '건가요', '가요', '연결', '하다', '이후', '상담항목', '항목', '배민1상', '도달', '한참', '한참대기', '나중', '끊킴', '상담자체', '자체', '피드백', '직원', '가지', '개선', '리뷰', '더하기', '더하기쿠폰', '쿠폰', '추천', '추천메뉴', '메뉴', '자체', '이유', '주소', '확인', '확인해본', '해본', '결과', '가요', '하나', '정렬', '최신', '최신순', '계획', '최근', '럭시쪽', '업데이트', '문제', '리뷰', '현상', '계신', '계신분', '노트', '노트10', '10', '사용중', '로그', '로그인시', '인시', '일시적', '연결', '불안정', '메시지', '출력', '출력후', '로그인', '불능', '플작동', '작동', '인트', '화면', '한로', '한로딩', '가게', '가게터치', '터치', '장바구니', '바구니', '메뉴', '주문', '주문버튼', '버튼', '터치시', '동일', '발생', '설치', '삭제', '반복', '태블릿', '탭7', '테스트', '테스트시', '정상', '정상작동', '원인', '무엇', '일주일', '동안', '한창', '장바구니', '바구니', '메뉴', '영업시간', '종료', '경우', '영업', '마감', '마감시간', '시간', '임박', '강조', '현재', '가게', '가게정보', '정보', '확인', '주문', '불편', '배달앱으로', '식당', '위생', '미디어', '이슈', '식당인지', '인지', '세스', '세스코멤버스', '코멤버스', '조리', '조리과정', '과정', '검증', '필터링', '재료', '부분', '투명', '리뷰', '주문자', '주문자본인', '본인', '리뷰', '개선', '맛조절', '조절', '옵션', '위와', '등록', '식당수가', '수가', '때문', '편리', '이용', '비회원', '주문', '결제', '완료', '처음', '2번', '반복', '확인', '확인차', '매장', '전화', '실수', '현장', '복잡', '과정', '외국', '호텔', '예약', '어플', '편리', '검색', '오류', '홈화면', '화면', '처음', '문제', '가기', '입력', 'ㄱ을', ...

# %% [markdown]
# ### 긍정 부정 비교

# %% [markdown]
# #### WordCloud

# %%
# 긍정 단어 확인
sentence_word_list_p = list(reviews.loc[reviews["reaction"] == "P", "nouns"])
word_list_p = sum(sentence_word_list_p, [])  # unpacking

sentence_word_list_n = list(reviews.loc[reviews["reaction"] == "N", "nouns"])
word_list_n = sum(sentence_word_list_n, [])  # unpacking

print(word_list_p[:5], word_list_n[:5])

counter_p = Counter(word_list_p)
counter_p_mc = dict(counter_p.most_common(30))
print(counter_p_mc)

counter_n = Counter(word_list_n)
counter_n_mc = dict(counter_n.most_common(30))
print(counter_n_mc)
# Out:
# ['주문', '주문시', '리뷰', '가지', '건의'] ['검색', '화면', '전체', '배달', '포장']
# {'리뷰': 95, '배달': 91, '메뉴': 90, '주문': 89, '기능': 88, '사용': 73, '가게': 66, '음식': 58, '불편': 53, '검색': 50, '추가': 42, '개선': 38, '이용': 36, '사람': 33, '가지': 31, '선택': 31, '사항': 30, '결제': 30, '경우': 28, '생각': 28, '감사': 26, '편리': 26, '가능': 24, '시간': 23, '하나': 21, '확인': 20, '다양': 19, '어플': 18, '쿠폰': 17, '사진': 17}
# {'배달': 291, '주문': 251, '가게': 141, '불편': 131, '사용': 116, '리뷰': 109, '시간': 105, '전화': 103, '업데이트': 95, '메뉴': 92, '쿠폰': 88, '결제': 85, '고객': 82, '확인': 77, '기능': 76, '화면': 75, '음식': 73, '문제': 69, '취소': 65, '이상': 63, '검색': 61, '개선': 61, '생각': 58, '오류': 58, '삭제': 55, '이용': 53, '로그': 52, '배달비': 52, '주세': 50, '센터': 50}

# %%
wordcloud_p = WordCloud(
    font_path="C:/Windows/Fonts/NGULIM.TTF"
).generate_from_frequencies(counter_p_mc)
plt.imshow(wordcloud_p)
plt.title("배달의 민족 긍정 리뷰 Word Cloud")
plt.axis('off')
plt.show()

wordcloud_n = WordCloud(
    font_path="C:/Windows/Fonts/NGULIM.TTF"
).generate_from_frequencies(counter_n_mc)
plt.imshow(wordcloud_n)
plt.title("배달의 민족 부정 리뷰 Word Cloud")
plt.axis('off')
plt.show()

# %%
# "불편"을 포함하는 긍정리뷰 확인
# print(reviews)
for i, s in reviews.iterrows():
    # print(type(s), s["score"])
    if '불편' in s["text"] and s["reaction"] == "P":
        print(s["score"], s["text"])


# 결론:
# 1. 부정적인 내용을 포함하지만 평점은 높게 준 리뷰들이 많음
# 2. 정말로 긍정적인 리뷰의 단어를 확인하고 싶다면 특정 키워드(ex. "불편")를 포함하는 리뷰를 제외하고 분석하는 것도 방법임
# Out:
# 5 앱 실행시에 로그인 여부를 먼저 물어보고 비회원 이용을 선택할 경우, 혹은 나중에 입력 선택 후 주문 결제 시 받을 주소를 설정하는 것으로 순서를 변경하면 어떨까요? 저는 필요할 때만 어플을 설치해서 삭제, 설치를 자주 하는 편인데요! 다시 사용하려고 재설치하고 실행하면 회원정보에 주소 저장을 해놨음에도 어플 실행하면 로그인 여부 안 물어보고 주소를 다시 설정해야해서 불편해요 ㅜ.. 처음에 주소를 설정해도 주문할 때 어차피 로그인할 건데 시간이 매번 추가로 드네요 저같이 어플을 사용하는 사람이 많지는 않겠지만 혹시 굳이 주문도 하지 않은 상태에서 주소부터 설정하는 이유가 따로 있을까요? 수정하기 어려운 사항이라면 제가 그냥 어플을 삭제하지 않고 사용하겠지만 순서를 바꾸는 정도라면 어렵지 않을 거 같고 사용자로서 굳이 주소부터 설정할 필요가 없을 거 같아서 의견 남겨봅니다! 어떨까요!
# 4 참 괜찮게 쓰고 있는데.. 검색결과화면에서 슬라이드로 다른 카테고리로 넘어가는 기능 민감도가 너무 높아서 불편해요 배달 카테고리 화면 아래로 내리던 중이었는데 포장으로 갑자기 넘어가고 자주 이러니까 다른 앱을 쓰게 될 정도로 영향이 있습니다 개선 바랍니다
# 4 오랫동안 애용중인 배민인입니다^^ 매장도 계속 추가되고 다양한 음식이 많아져서 정말 좋습니다. 하지만 아쉬운게 있다면, 메뉴사진이 추천메뉴에만 있어서 메뉴선택이 어려워요. 사진이 모두 있다면 메뉴선택이 더 수월할것같아요. 그리고가게 운영시간이 실제 운영시간과 맞지않은 곳이 몇몇있어서 불편함이 있고, 어느 가게는 배송료를 현금으로 받는곳이 있어서 현금이 없을땐 주문을 할 수 없어 아쉬워요. 어플사용에 항상 좋은 환경이 되게 개선 해주셔서 감사하며, 위 사항도 개선된다면 정말 더 좋을것 같아서 적었습니다. 수고하세요^^
# 4 배달앱 중에선 배민이 제일 편한거 같아요~ 몇 년 사용하면서 꽤 불편하다고 느낀점이 있는데 가게 메뉴들 리스트에 적혀있는 설명(보통은 메뉴의 구성을 적어둡니다)과 메뉴를 선택해서 들어가면 보이는 설명이 다를 경우에 리스트에 적혀있는 글이 잘려서 다 안보이면 뒷내용을 알 수 없다는 점이예요. 사진에서 메뉴 구성을 한 눈에 볼 수 있는 메뉴들은 괜찮지만 마라탕과 같이 조리시 사진이 찍혀있는 경우 구성품을 전부 알기 힘든 경우에는 사리를 추가하거나 빼는것이 굉장히 난해합니다. 이런점 때문에 지난 몇 년간 같은 불편함을 격고 있습니다. 주변 지인분들도 공감하시더라구요. 개선되었으면 하네요.
# 4 1. 메뉴 선택란에서 해당 메뉴를 주문한 사람의 리뷰를 볼 수 있는 기능이 있었으면 좋겠습니다. 주문하기 전 특정 메뉴에 대한 리뷰를 보고 싶은데 직접 리뷰란을 스크롤하면서 찾기 너무 번거롭고 불편합니다. 다른 배달앱인 요*요에는 예전부터 있었던 굉장히 유용한 기능인데 배민에도 생겼으면 좋겠습니다. 2. 배달팁 낮은순 정렬 시스템이 개선되었으면 좋겠습니다. 배달팁이 저렴한 곳을 찾고 싶어서 그 기능을 사용하는건데 배달팁이 500~1000원인 가게보다 0~5000원인 가게가 더 먼저 뜹니다. 근데 5만원 이상 주문시 0원, 그 이하는 5000원 이러는 가게가 너무 많다보니 짜증이 안 날 수가 없습니다… 그냥 단순히 최소 배달팁 순으로 정렬되는 것이 아니라 직접 원하는 배달팁의 범위를 설정하는 식으로 개선되면 좋을 것 같습니다.
# 5 안녕하세요 개발자님. 항상 배달의 민족 편리해서 잘 이용하고 있습니다. 다만 아쉬운 점이 두가지가 있는데요. 첫째. 교환권이 있을때 늘 전화로하면서 교환권 바코드 번호를 불러 드려야지만 주문이 가능한데 배달의 민족에서도 주문할때 교환권 바코드 번호 입력해서 번거롭지 않게 앱에서도 교환권으로 결제 기능이 있었으면 좋겠어요. 둘째. 전화 주문도 결제 완료건에 한해서만 누적 주문 횟수로 가능하게끔 해주셨으면해요 불편사항은 없고 다음 업데이트때 이 두가지 됬으면 좋겠네요~
# 5 안녕하세요. 몇 년간 어플을 잘 사용하고 있는 유저입니다. 그런데 어플을 꽤 오래 사용하다보니 조금 불편한게 생겼습니다. 배달을 자주 시켜먹다보니 많은 가게들을 찜해놓게 됐는데, 찜한 가게가 많이 쌓이다보니 제가 원하는 가게를 찾기가 조금 번거롭습니다. 원하는 가게를 찾기 위해서는 스크롤을 하염없이 내려야합니다. 내가 찜한가게 내에 검색기능이나, 아니면 카테고리를 분류해서 볼 수 있는 기능이 추가된다면 사용하기에 조금 더 편리할 것 같습니다. 그리고, 찜한 가게를 선택해서 한 번에 여러개 해제할 수 있는 기능도 있으면 좋겠습니다. 찜해놓은 가게들 중 일부가 폐업 등의 이유로 주문이 불가하게 됐는데, 목록에서 자동으로 삭제가 되지 않고 남아있더라구요. 그런데 한 번 찜을 해제할 때마다 자꾸 목록이 맨 위로 올라가는 바람에 여간 번거로운게 아닙니다ㅠㅠ 목록이 보고있는 페이지가 고정되거나, 혹은 선택 삭제를 할 수 있는 기능이 있으면 좋을 것 같습니다. 감사합니다.
# 5 최근 기능 업데이트이후에 전면메서 메뉴를 한번에 볼 수 있어서 좋아진 것 같아요. 기능적으로 불편한 건 없지만 비즈니스적으로 업주가 별5점 강요 및 서비스를 제공하는 부분은 어느정도 검열이 필요해보입니다. B마트의경우, 셀렉션확장을 주력으로 하는것이 중요해 보이며, 본래의 컨셉에 맞는 밀키트에 주력하고, 마진구조 개선을 위해 PB도 고민할 필요가 있습니다. 타겟에거 맞추고 비즈니스의 고유한 방향은 유지해야하지만, 마케팅적으로 모객할수있는 구색도 갖춰져야합니다. 코로나때문에 어려움은 있지만 바캉스/휴가 관련한 편의 제품을 구비하는것도 좋을 듯 합니다. (체온계, 방수팩, 물총, 썬크림, 셀카봉 등등)
# 5 잘 사용하고 있습니다. 그런데 개인적으로 메인화면에 검색아이콘이 바로 보였으면 하는 아쉬움이 있습니다. 처음에는 검색기능이 없는줄알고 불편하다 생각해서 앱을 쓰지 않았는데, 메인화면에서 아래로 내려보니 있더군요. 상단 우측에 돋보기 버츤 하나 있으면 편할 것 같다는 생각이 들었습니다.
# 5 음식메뉴 고를때 옵션 추가 또는 삭제가 장바구니서, 가능하게 세부적인 선택 기능이 만들어지면 좋겠습니다. 그게 안되니까..골랐다가 더추가나, 해제를 못해 전체음식 삭제하고, 다시 골라야해서 조금 불편해요. 기능개선이 이루어지길 기대해봅니다. 예를 들어, 된장찌개에 옵션이 차돌.해물...등이있어 차돌로했다가..다시 해물로 바꾸고싶으면, 장바구니에서 옵션변경이 가능하게..ㅎ 무슨얘긴줄 아시겠죠?ㅎㅎ
# 5 그가게의 특정메뉴를 클릭하면 그메뉴의 리뷰만 볼 수 있는 기능도 있었으면 좋겠습니다. 예를들면 ○○떡볶이집에 로제떡볶이메뉴를 클릭하면 그 메뉴의 리뷰만 볼 수 있는 기능이요! 그리고 가끔 옛날에 내가 이가게에 무슨 메뉴를 먹었었는지 까먹는 경우가 있는데 주문내역을 계속 내려서 찾기가 불편합니다. 그럴때 검색으로 빨리 찾을 수 있는 그런 기능도 있었으면 좋겠습니다.
# 4 잘사용하고 있습니다 새로 생긴 배민원 상점 리스팅 방식이 불편합니다. 한번에 여러개보고 싶은데 사진이 너무 커서 배달 시간, 배달팁 같은 글씨도 눈에 잘 안 들어옵니다. 대부분 사진대로 안와서 오히려 실망이 큽니다. 전 방식이 좋은 것 같아요 그리고 메뉴별 리뷰 모아보기 기능이 있었으면 좋겠습니다.
# 5 배달의 민족이 대한민국 최고의 배달앱이라는 것은 뜻깊이 인정하고 있습니다. 타 회사의 배달앱보다도 확연한 차이가 있으며 정말로 최고의 배달앱입니다. 그런데 한 업소에서 한 카테고리(야식)에서 동일한 업소가 8개이상 중복되어 나타나는 경우가 있습니다. 물론 같은 카테고리에서 광고 허용 범위의 제한이 없더라도 같은 카테고리에서 광고의 개수를 제한하지 않는데에 있어서 불편함이 많습니다. 흔히 도배라고 하죠. 이런 것을 막기위해 최소한으로 같은 카테고리의 광고 개수를 제한하는 것을 요청드리고자 합니다. 긴 글 읽어주셔서 감사드리며 감사인사 드립니다. 지금 코로나19시대에 걸맞는 최고의 앱입니다. 항상 수고하시고 응원하겠습니다.
# 4 안녕하세요 배민을 거의 매우 이용하는 사람입니다. 한 가지 건의사항이 있어서 리뷰를 남겨봅니다. 현재 다양한 기능이 생기면서 많이 편리해졌습니다. 하지만 배달팁 2,000원 이하 1,000원 이하를 설정해도. 배달팁 0~4,000 이런 가게도 검색이 됩니다. 1인분만 시켜먹는 저로썬 상당히 쓸모 없고 불편합니다. 그래서 건의하고 싶은 내용은 최소 배달팁, 최대 배달팁 항목이 추가되어 최소 1,000원 이하 ~ 최대 2,000원 이하 이런식으로 설정해 배달팁 1,000원 ~ 3,000원으로 등록된 가게들은 출력이 안되도록 했으면 좋겠습니다.
# 4 1. 메뉴별로 리뷰를 볼 수 있는 기능이 있으면 좋겠습니다. 내가 시키려는 메뉴가 맛있는지 바로 확인이 안되어 불편합니다. 2. 리뷰창에서 제가 쓴 리뷰만 골라 볼 수 있으면 좋겠습니다. 맛있게 먹었던 집이었는지 기억이 잘 안나는 경우가 많아요. 3. 리뷰를 작성하고 확인 버튼이 안보입니다. 이게 전에 개선이 된 것 같았는데 또 그러네요. 사진첨부를 클릭했다가 다시 돌아와야만 확인버튼이 보입니다. 리뷰 쓸때마다 너무 불편합니다. Lg 벨벳 사용자입니다.
# 5 음식 메뉴에 있는 작은 회색 설명 부분이 잘리는게 불편해서 음식의 상세페이지에서라도 볼 수 있게 해달라고 리뷰 올렸었는데 이번에 개선되어서 너무 좋아요! 역시 똑똑쟁이들이 모인 회사로구먼 ------------ 이전리뷰 ------------ 정말 잘 쓰고 있는 앱이에요. 근데 음식 메뉴에 있는 작은 회색 설명 부분을 음식의 상세페이지에서라도 볼 수 있게 개선해 주실 수 있나요? 그 부분에 세트메뉴 구성에 대한 소개가 많은데 자꾸 중간에 잘려서 정보를 온전히 전달받지 못하는 게 조금 많이 아쉽네요. 하나 뺀 별점은 이 부분이 개선되면 다시 추가하러 오겠습니다!
# 5 요*요 사용했다가 넘어와서 배민에 정착한 이용자입니다. 저는 나름 만족하면서 정말 잘 사용하고 있지만 몇가지가 너무 불편해서 이렇게 적어봅니다. 메뉴를 클릭했을때 해당 메뉴의 리뷰를 볼 수 있는 기능이 없어서 너무 불편합니다. 리뷰에 들어가서 어떤지 일일히 확인하는게 불편해요 ㅠㅠ 그리고 음식 카테고리에 '전체' 를 넣어주셨으면 좋겠습니다. 배민 잘 사용하고 있습니다. 유저들의 불편사항을 개선하고 잘 들어주었으면 하는 작은 바램으로 짧게나마 글을 적습니다. 일 화이팅 하세요~
# 4 배달의 민족 대체로 잘 이용하고 있는데 한가지 꼭 건의드리고 싶어서 리뷰에 남깁니다. 저는 20대이니까 큰 상관이 없지만 시력이 좋지 않으신 부모님들께서 음식을 시키실 때 한 가지 불편함이 있었습니다. 포장주문이 아닌 배달로 음식을 받기 원할때는 우선 주소를 선택하고 매장을 선택한 뒤 음식을 선택하면 되잖습니까. 그런데 부모님께서 매장을 선택하는 과정 중에 같은 매장이라도 배달에 해당하는 것과 포장주문에 해당하는 것이 따로 나뉘어져 있는데 이 두 개를 구분하기가 쉽지 않았다고 합니다. 단순히 매장 옆에 아주 작은 하얀 글씨에 검은 타원형 버튼 모양으로 포장이라고 적혀있는데 평균 시력 이하이신 분들이 구별하기가 쉽지 않을 것 같더군요. 이 문제점을 개선해주셨으면 좋겠어요. 주소 선택 후 검색이 되면 포장주문 란과 배달 란을 아예 따로 구분해놓도록 하는 방식을 추가해주시는 등 배달의 민족 측에서 현재보다 더 나은 접근성을 위해 힘써주셨으면 좋겠습니다!
# 4 잘쓰고있어요 그런데 몇개만 개선해주셨으면해서ㅠ 1.음식점 메뉴별로 후기 볼수있게해주세요 2.정확히 뭐뭐시켰는지 뭘추가했눈지 다 뜨게해주세요 맛있어보여도 뭔지를 모르니깐 시킬수가ㅠ 3.사진리뷰 전체보기가능하게해주세요 그래서 전체보기해서 맛있어보이는 사진 눌러서 그메뉴 확인하고 주문할수있게 그러면 너무편할거같아요.. 2,3까진 그렇다치고 1이 너무간절해요 1이안되서너무불편해요
# 4 좋아요! 한가지 요청 사항이 있어요. 불편한것이 있어 개선점이 필요해요. 가족 계정을 회사원들과 랜선 회식으로 많이 씁니다. 그런데 이게 집 주소를 어쩔수없이 오픈해야해서 불편해요ㅠㅜ 알려주기싫을 때도 있는데요, 주소 비공개를 선택사항으로 만들어줬으면 좋겠습니다. 대표자가 결제할 때 더보기 눌렀을때 그냥 주소는 공란으로 보였으면 해요. 가족계정을 꼭 가족이 쓰는게 아니라는것도 코로나 시대에 랜선회식때 이용 많이 한다는걸 알아주셨으면 합니다. 마찬가지로 메뉴비공개도 가능하면 좋겠네요~ 가게명까지는 보여도... 감사합니다!
# 5 진짜 좋아요! 배달 시켜 먹기 편리하고 몇분 남았는지 얼마 결제 되는지도 뜨고 여러가지 결제 방법이 있어서 정말 좋았어요! 여러번 시켜 먹었는데 불편한점 하나도 없었고 편하게 잘 사용했습니다! ㅜㅜ 불편한 점 있는 사람들만 여기 리뷰 쓰러 오나봐요 저는 편하게 잘 사용했어요!
# 5 배민 잘 이용하고 있습니다. 그런데 한가지 불편한 점이 있네요. 음식점 목록을 보면 제가 있는 곳의 주소로 절대 오지않는 음식점들도 목록에 뜨는게 싫어요. 시키고 싶어도 시킬 수가 없는 곳이니 말이죠. 이런 문제때문에 배달 오지 않는 음식점을 목록에서 지울 수 있는 기능도 있었으면 합니다.
# 4 카테고리 세부수정이 필요해 보입니다. "반찬" 검색하면 반찬전문점이 상위노출이 되어야 하는데 돈까스. 참치.카페 등 기준없이 목록이 뜹니다. 매우 불편하네요. 한가지 더, 지원금 받고 지역화폐 결제 시즌에 다수의 업주들이 눈먼돈이라고 생각하는지 서비스품질이 불쾌를 넘어 분노를 일으킬때도 있는데 이점도 개선 방안을 마련해주세요.
# 5 요즘 같은 시국에 밖에 나가서 먹기도 힘들어서 잘 사용하고있는 어플입니다. 다만 예전부터 한가지 추가해주셨으면 하는 기능이 있어서 리뷰 남깁니다. 가게별 리뷰를 보면 시간순/별점 높은순/별점 낮은순으로만 볼 수 있습니다. 여기에 메뉴별 리뷰도 추가되면 좋겠습니다 리뷰가 궁금한 메뉴가 있는데 해당 메뉴에 대한 리뷰를 보려면 하나씩 확인해야해서 너무 불편합니다
# 5 원래 잘 쓰고 있는데.. 아쉬운점이 있어서 리뷰남깁니다. 요즘 리뷰이벤트로 별점이라던지 좋은리뷰를 강요하는 곳이 많아지는거 같네요. 이러면 네이× 블로그 거지들 마냥 바뀌는거 아쉽습니다. 요즘 리뷰이벤트 하는곳 믿고 거릅니다. 그리고, 각 업체별로 많이 주문된 메뉴를 볼 수 있는 기능은 없나요? 그 기능있으면 여기×, 배x통 같은 어플 제칠거 같은데 말이죠. 맨날 리뷰보고 메뉴다시 넘어가서 보고... 너무 불편해요. 개선 부탁드립니다.
# 5 평소에 잘 사용하고있습니다! 최근 바뀐 배민은 좀 많이 불편하긴하네요ㅠㅠㅠㅠ 요즘 배민을 쓰다보니 든 생각인데 리뷰로 갑질하는고객이 많듯이 갑질하는사장도 많다고 생각이 듭니다. 그래서 뭔가 이가계 표시하지않기 이런기능같은거 뭔가 있으면 좋을것같다는 생각이 듭니다!ㅠㅠㅠㅠ 최근에 별로였던곳이면 기억을하겠지만 시간이좀 지났거나 상표사진이 변경되거나 가까운곳에 다른지점이있거나 하는곳은 헷갈려서 아에 안보이면 좋겠다 라는생각이 들어다구요..
# 4 다 좋은데 메뉴별 리뷰를 바로바로 볼수있었으면 좋겠습니다. 일반 메뉴를 시키려고 그 메뉴 리뷰를 찾으려 둘러보면 시간도 오래걸리고 불편합니다.. 다른 배달 플랫폼은 그게 참 편한데 배민은 없어서 불편해요. 그리고 음식점 차단,숨김 혹은 블랙리스트에 넣는 기능이 있었으면 좋겠어요. 주문시키다보면 서비스가 마음에 안들거나 음식의 질과양이 매우떨어지는 가게는 리스트에서 제외시켜서 보고싶은데 그런 기능이 없어 이또한 불편합니다. 주문을 가게에서 받아놓고 결국 다음날 아침까지 배달 안보내다가 가게 문 열 시간이 되어서 사과도없이 주문만 딸랑 취소시키고 이런식으로 서비스 뭣같이 하는 가게들이 있는데 개인차단기능 꼭 있었으면 좋겠습니다..
# 5 메뉴 리스트에서 제품명 밑에 설명이 길어지는 경우 ... 숨김처리되는데, 클릭해서 상세 메뉴 정보로 넘어가도 해당 정보를 볼 수가 없어서 사장님들이 적어둔 메뉴 상세 정보를 볼 수가 없어 불편합니다. 개선해주시면 이용하기 편할 것 같아요
# 4 주문한내역 중에 검색할수 있었으면 좋겠어요 예전에 시킨 내역도 뭐였드라 하면서 찾게되는데 일일이 확인해야되서 불편하네요! 꼭 반영부탁드려요!
# 4 배달시 요청사항이 저장이 안되네요 (직접입력할때요) 이전에는 됬었는데... 오히려 더 불편한거 같아요
# 5 찜 목록을 폴더별로 볼 수 있도록 폴더기능 추가해주셨으면 좋겠어요 많이 저장하면 제일 오래전에 찜했던 가게는 없어지는것도 불편하고 기숙사때문에 두개지역 왔다갔다하는데 저같은 사람 꽤 많을 것 같아서요
# 4 지방 사업장입니다 요즘처럼 눈이내리면 배달불가한 지역이 생깁니다 공지사항에올려도 주문자가 바로볼수없어서 불편해요 공지사항인데 그걸보려고 다른페이지로 넘어가는 사용자는 없을듯 합니다 공지사항은 첫회면에 나와야된다고 생각듭니다
# 5 진짜 다 좋은데 사람들이 작성한 리뷰에 해당 음식 리뷰만 볼 수 있게 검색하는 기능이 있었으면 좋겠어요. 저는 "이 음식"이 먹고싶어서 처음시켜먹는 거니까 평을 보려고 리뷰란에 들어갔는데 아무리 내려도 다른 음식 리뷰만 뜨고 한 20개 넘기면 내가 찾던 음식 1개 나오니까 너무 불편해요ㅠㅠ 이거 빼고는 괜찮습니다.
# 4 폰에서 검색후 상하 스크롤 하는데 자꾸 옆쪽으로 가지네요. 그리고 긴 페이지에서 위로가기 버튼이 없어 불편해요.
# 5 다좋은데 포장 주문할때 포장은 만나서 결재가 없어서 약간 불편해여
# 4 언제부턴가 이전 결제방식 자동저장 기능이 없어졌네요. 자주 주문하는 입장에선 많이 불편합니다.
# 5 모든 배달 어플이 불편함없이 쓸 수 있다지만 기능 과잉의 시대에 배달의 민족 어플은 그나마 다른 어플에 비해서 깔끔한 편이다.
# 5 저는 배달의민족을 정말자주 사용하는사람입니다. 리뷰쪽 개선을해줬음 해서 글을써봅니다 리뷰보기에서 내가원하는(먹고싶은) 메뉴가 이집이 맛이있는지없는지 궁금할때가 많은데요 사람들 리뷰가많다보니 먹고싶은메뉴 리뷰를찾아야하는 불편함이있어요. 내가원하는 그 메뉴만 딱 찾아서 리뷰보기 기능이있었으면 좋겠습니다.
# 5 배민오더에 들어가서 맛집을 찾아보려고 하는데 이용점포가 너무 많이 몰려있는 지역은 보기가 힘드네요 원하는 카테고리만 필터해서 볼 수 있도록 해주면 좋겠어요! 예를들면 분식을 찾아보고싶은데 그 외 다른종류의 집들이 너무많이떠서 찾아보는데 시간이 오래걸리고 불편함이있네요 그래서 보려다가 포기하게됨..
# 4 어떤사람이든 불편하다고 할만한거 3가지만 말씀드릴게요. 1.검색기능이 왜 아래에있죠? 모든 웹사이트,어플들의 검색기능이 왜 위에 있는지 모르는분이 만든건가요? 이해가안가네요 위에있으면 손가락 뻗어야해서 그런건가; 2.지정휴업일 이면 그냥 휴업이라고 써주세요 준비중이라길래 이집은 모바일결제가 안되는줄알고 전화했건만 휴업이라고 하네요. 3.음식카테고리가 처음부터 펼쳐져있는거 불편합니다. 처음부터 그냥 카테고리가 닫혀있고 카테고리를 눌렀을때 펼쳐지게해주세요 제가 국뽕이라 웬만하면 한국회사꺼 사용하려고하는데 이건 너무 불편해서 못쓰겠어요
# 4 주소 선택할 때 자주 쓰는 주소는 밑으로 내려가고 새로 만든 주소는 위로 올라와서 불편하네요. 우리집, 회사 외에 추가 즐겨찾기 주소를 만들 수 있었으면 좋겠어요
# 5 앱 기능은 다 좋아요. 선택 메뉴도 직관적으로 잘 분리되어있고 검색 필터도 다 잘 사용중이예요. 그래서 별 5개로 평가했는데 한가지 더 있었으면 좋을만한 기능이 있어서 리뷰남겨요. 제가 평소에 찜 기능을 유용하게 사용하고 있는데 점점 찜한 가게 수가 많아지다보니 찾기가 힘들고, 또 제가 배민을 주로 사용하는 주소지 지역이 2-3곳이라서 주소지 별로 다 섞여있다는 게 조금 불편합니다. 예를들어 A치킨집 신촌점이랑 제주점 같은 게 섞이다보니 매번 제가 알아서 구별해야하는 게 불편해요. 그래서 현재는 찜 기능 안에서 배달포장, B마트, 배민스토어, 쇼핑라이브로만 구분이 되어있지만 배달포장 안에서 제가 원하는대로 그룹을 생성해서 분류할 수 있었으면 좋겠어요. 이게 힘들다면 현재 주소지에서 배달가능한 곳만 뜨고, 거기서 음식분류별 구분 정도는 되었으면 좋겠네요. 치킨/양식/한식 이런식으로요. 배민 앱을 오래 쓰면서 유일하게 개선되었으면 하는 부분이었어요. 의견 반영해주신다면 감사하겠습니다.
# 4 리뷰를 메뉴당 볼 수 있을까요? 가령 쿠팡에서 상품 열면 그 상품에 대해서만 리뷰가 들어가잖아요? 그런데 배민은 리뷰가 그 가게 전체 서비스와 전체 메뉴 중에서 제가 먹고 싶은 메뉴를 찾아서 확인해야 해서 좀 불편해요. 요즘 보니 주문자가 시킨 메뉴에 대해 한 줄 리뷰를 쓰게 되어 있는데 그 리뷰만이라도 해당 메뉴 밑에 정렬되면 메뉴 결정할 때 큰 도움이 될 거 같아요. 식당이 아무리 잘해도 맛난 주력 음식과 구색 맞추기가 따로 있어서 간혹 뭐가 맛있는지 찾아보려고 전체 리뷰를 모두 훑기 귀찮을 때 메뉴당 리뷰는 편의자 중심의 서비스를 제공한다고 생각합니다.
# 4 다 좋은데 이번에 수저포크 자동으로 빼게 선택되는건 너무 불편해요 ㅠㅠ.. 필요한데 자동으로 비선택 돼잇으니 시키고 나서 알게되네요... 기본옵션은 수저주게 하고 선택으로 미필요로 바꾸는게 나을거같아요...
# 4 불편사항이 있어 남깁니다 배민스토어 이용해보았는데요 마트에 들어가 검색을 누르고 상품을 장바구니 담은뒤 백키를 누르면 전체검색화면이 뜹니다 그리고 한번 더 눌러야 원래 제가 찾는 마트화면이 나옵니다 이게 한두가지 상품 검색을 할 땐 괜찮은데 여러 상품 검색후 다시 되돌아갈때 두번씩 계속 클릭해야하는게 너무 불편합니다 ㅜㅜ 오류인건지 일부러 이렇게 만드신것인지 모르겠으나 개선이 필요해보입니다 ㅜㅜ
# 5 다 좋은데 딱 한가지만 바뀌었으면 좋겠습니다! 비조리/조리되는 요리 중 비조리가 기본 옵션인게 조금 불안하고 불편합니다. 조리를 기본 옵션으로 해주셨으면 개선이 될 거 같습니다! 감사합니다.
# 5 가장 많은 업체가 등록이 되어있는거 같네요. 사용하며 특별히 불편한점은 없지만 업체마다 배달료가 추가되는 곳은 메뉴에서 같이 결제가 되게끔 개선하면 좋겠네요.
# 4 다 좋은데요. 메뉴검색을 그 가게 한정이 아니라, 검색엔진처럼 음식검색하면 그 메뉴가 있는 가게이름들과 음식이 나왔으면 합니다. 이건 뭐 가게마다 일일이 들어가서 찾아야하니 약간 불편하네요.
# 5 우선 전화하는 걸 싫어하는 저같은 입장에서 배달앱은 진짜 너무나 사랑입니다. 배민 덕분에 맛있는 음식들 편하게 잘 시켜서 먹는데 바로 이전 버전 업데이트 이후로 숟가락과 젓가락은 일일이 체크해서 달라고 해야되는 점은 살짝 불편합니다.. 깜빡하고 넘어가면 기본적으로 안 온다에 체크가 되어있어서 없이 오는데 차라리 반대로 필요없는 분들이 필요없다고 체크하는 게 편할 것 같아요 ㅠㅠ 숟가락 달라고 바쁘신 음식점에 전화하기도 조금 눈치 보이고요..! 이 부분만 제외하면 다 좋아요 !
# 4 다 만족스러운데 검색기능을 추가해주시면 안될까요?? 찾고싶은 음식점을 찾을때마다 스크롤을 밑에까지 내리는것도 불편하고 프랜차이즈를주문한다고했을때 한지점만 뜨니까 검색기능을만들면 여러 지점도 검색할수있고 좋을것같아요.
# 5 어플 정말 잘 이용하고 있습니다. 다만 기능이 추가 되었으면 하는 부분이 있습니다. 가게의 리뷰를 볼때 원하는 메뉴에 대한 리뷰를 선택해서 볼 수 있으면 좋겠습니다. 그 메뉴에 대한 리뷰가 궁금한데 처음부터 끝까지 찾아가면서 봐야해서 불편하더라구요!
# 5 업자입니다. 솔직히 따른(요기요나 쿠팡이츠등)어플은 사용하기가 너무 불편합니다. 메뉴 수정도 맘대로 안되고 정말 많이 번거롭습니다. 그해 비해 배민은 관리도쉽고 매장도 많아서 사용하시기 훨씬좋습니다
# 4 잘 사용하고잇습니다~ 놀러가서도 사용할수잇어서 편하구요ㅎㅎ 다만..제가 친구네서 시켯을때는 결제창에 퀵비가 같이 결제가되엇는데 저희집에서 시키려하니 같이결제가 안되더라구요..? 이게 지역마다 다르게 나오는건가요?ㅠㅠ꼭 현금으로 해야되서 너무 불편해요..카드밖에없을때는 어찌시켜먹나용....?ㅠㅠㅠㅠ

# %%
# "불편"을 포함하지 않는 긍정리뷰로 wordcloud 진행

sentence_word_list_p = list(reviews.loc[reviews["reaction"] == "P", "nouns"])
sentence_word_list_p2 = [s for s in sentence_word_list_p if "불편" not in s]
word_list_p2 = sum(sentence_word_list_p2, [])  # unpacking

print(len(word_list_p), len(word_list_p2))
print(word_list_p[:5], word_list_p2[:5])

counter_p2 = Counter(word_list_p2)
counter_p2_mc = dict(counter_p2.most_common(30))
print(counter_p2_mc)

wordcloud_p2 = WordCloud(
    font_path="C:/Windows/Fonts/NGULIM.TTF"
).generate_from_frequencies(counter_p2_mc)
plt.imshow(wordcloud_p2)
plt.title("배달의 민족 긍정 리뷰2 Word Cloud")
plt.axis('off')
plt.show()
# Out:
# 4671 3502
# ['주문', '주문시', '리뷰', '가지', '건의'] ['주문', '주문시', '리뷰', '가지', '건의']
# {'주문': 75, '리뷰': 75, '배달': 75, '메뉴': 65, '기능': 62, '사용': 59, '가게': 54, '음식': 46, '검색': 35, '추가': 27, '이용': 26, '사람': 25, '생각': 23, '가지': 22, '편리': 22, '사항': 21, '결제': 21, '경우': 21, '가능': 20, '감사': 20, '선택': 20, '개선': 19, '쿠폰': 17, '하나': 17, '다양': 17, '시간': 16, '확인': 14, '어플': 14, '주세': 14, '건의': 13}

# %% [markdown]
# #### 연관성 분석

# %%
from apyori import apriori

# sentence_word_list_p = list(reviews.loc[reviews["reaction"] == "P", "nouns"])
# sentence_word_list_n = list(reviews.loc[reviews["reaction"] == "N", "nouns"])
print(len(sentence_word_list_p), len(sentence_word_list_n), len(sentence_word_list_p2))
# Out:
# 271 729 218

# %%
# 긍정 리뷰
apri_p = list(apriori(sentence_word_list_p, min_support=0.05))
df_apri_p = pd.DataFrame(apri_p)
print(df_apri_p.sort_values("support", ascending=False).head())

df_apri_p["length"] = [len(i) for i in df_apri_p["items"]]
# print(df_apri_p.tail())

df_apri_p = df_apri_p.loc[df_apri_p["length"] == 2]
print(df_apri_p.shape)
print(df_apri_p.sort_values("support").head())
# Out:
#    items   support                      ordered_statistics
# 13  (배달)  0.335793  [((), (배달), 0.33579335793357934, 1.0)]
# 11  (리뷰)  0.328413   [((), (리뷰), 0.3284132841328413, 1.0)]
# 30  (주문)  0.328413   [((), (주문), 0.3284132841328413, 1.0)]
# 9   (기능)  0.324723   [((), (기능), 0.3247232472324723, 1.0)]
# 12  (메뉴)  0.324723   [((), (메뉴), 0.3247232472324723, 1.0)]
# (62, 4)
#         items   support                                 ordered_statistics  \
# 49   (음식, 가게)  0.051661  [((), (음식, 가게), 0.05166051660516605, 1.0), ((가...
# 52   (배달, 가지)  0.051661  [((), (가지, 배달), 0.05166051660516605, 1.0), ((가...
# 69   (사람, 기능)  0.051661  [((), (사람, 기능), 0.05166051660516605, 1.0), ((기...
# 62   (결제, 사용)  0.051661  [((), (결제, 사용), 0.05166051660516605, 1.0), ((결...
# 103  (음식, 추가)  0.051661  [((), (음식, 추가), 0.05166051660516605, 1.0), ((음...
#
#      length
# 49        2
# 52        2
# 69        2
# 62        2
# 103       2

# %%
# 긍정 리뷰2
apri_p2 = list(apriori(sentence_word_list_p2, min_support=0.05))
df_apri_p2 = pd.DataFrame(apri_p2)
print(df_apri_p2.sort_values("support", ascending=False).head())

df_apri_p2["length"] = [len(i) for i in df_apri_p2["items"]]
# print(df_apri_p.tail())

df_apri_p2 = df_apri_p2.loc[df_apri_p2["length"] == 2]
print(df_apri_p2.shape)
print(df_apri_p2.sort_values("support").head())
# Out:
#    items   support                      ordered_statistics
# 14  (배달)  0.344037   [((), (배달), 0.3440366972477064, 1.0)]
# 29  (주문)  0.344037   [((), (주문), 0.3440366972477064, 1.0)]
# 12  (리뷰)  0.321101   [((), (리뷰), 0.3211009174311927, 1.0)]
# 13  (메뉴)  0.298165   [((), (메뉴), 0.2981651376146789, 1.0)]
# 9   (기능)  0.284404  [((), (기능), 0.28440366972477066, 1.0)]
# (53, 4)
#        items   support                                 ordered_statistics  \
# 46  (배달, 가지)  0.050459  [((), (가지, 배달), 0.05045871559633028, 1.0), ((가...
# 50  (검색, 배달)  0.050459  [((), (검색, 배달), 0.05045871559633028, 1.0), ((검...
# 52  (결제, 사용)  0.050459  [((), (결제, 사용), 0.05045871559633028, 1.0), ((결...
# 55  (주문, 경우)  0.050459  [((), (주문, 경우), 0.05045871559633028, 1.0), ((경...
# 60  (음식, 기능)  0.050459  [((), (음식, 기능), 0.05045871559633028, 1.0), ((기...
#
#     length
# 46       2
# 50       2
# 52       2
# 55       2
# 60       2

# %%
# 긍정 리뷰1에는 있으나 긍정 리뷰2에는 없는 아이템 확인
for p1 in list(df_apri_p["items"]):
    if p1 not in list(df_apri_p2["items"]):
        print(p1)
# Out:
# frozenset({'음식', '가게'})
# frozenset({'추가', '가게'})
# frozenset({'리뷰', '개선'})
# frozenset({'메뉴', '개선'})
# frozenset({'불편', '개선'})
# frozenset({'불편', '검색'})
# frozenset({'불편', '기능'})
# frozenset({'사람', '기능'})
# frozenset({'불편', '리뷰'})
# frozenset({'불편', '메뉴'})
# frozenset({'불편', '배달'})
# frozenset({'불편', '사용'})
# frozenset({'주문', '불편'})
# frozenset({'추가', '불편'})
# frozenset({'추가', '선택'})
# frozenset({'음식', '추가'})

# %%
# 부정 리뷰
apri_n = list(apriori(sentence_word_list_n, min_support=0.05))
df_apri_n = pd.DataFrame(apri_n)
print(df_apri_n.sort_values("support", ascending=False).head())

df_apri_n["length"] = [len(i) for i in df_apri_n["items"]]
# print(df_apri_n.tail())

df_apri_n = df_apri_n.loc[df_apri_n["length"] == 2]
print(df_apri_n.shape)
print(df_apri_n.sort_values("support").head())
# Out:
#    items   support                      ordered_statistics
# 19  (배달)  0.399177   [((), (배달), 0.3991769547325103, 1.0)]
# 40  (주문)  0.344307   [((), (주문), 0.3443072702331962, 1.0)]
# 0   (가게)  0.193416   [((), (가게), 0.1934156378600823, 1.0)]
# 21  (불편)  0.179698  [((), (불편), 0.17969821673525377, 1.0)]
# 23  (사용)  0.159122  [((), (사용), 0.15912208504801098, 1.0)]
# (31, 4)
#        items   support                                 ordered_statistics  \
# 56  (주문, 고객)  0.050754  [((), (주문, 고객), 0.05075445816186557, 1.0), ((고...
# 58  (주문, 기능)  0.050754  [((), (주문, 기능), 0.05075445816186557, 1.0), ((기...
# 60  (배달, 리뷰)  0.050754  [((), (리뷰, 배달), 0.05075445816186557, 1.0), ((리...
# 75  (음식, 주문)  0.050754  [((), (음식, 주문), 0.05075445816186557, 1.0), ((음...
# 73  (쿠폰, 사용)  0.050754  [((), (쿠폰, 사용), 0.05075445816186557, 1.0), ((사...
#
#     length
# 56       2
# 58       2
# 60       2
# 75       2
# 73       2

# %%
# 네트워크 분석 시각화
import networkx as nx
import numpy as np
from matplotlib import pyplot as pyplot

plt.rc('font', family="NanumGothic")

# 긍정 리뷰1
G = nx.Graph()
ar_p = df_apri_p["items"]
G.add_edges_from(ar_p)

pr = nx.pagerank(G)
nsize = np.array(list(pr.values()))
nsize = 2000 * (nsize - min(nsize)) / (max(nsize) - min(nsize))

pos = nx.kamada_kawai_layout(G)

nx.draw(G, pos, node_size=nsize, with_labels=True, font_size=10, font_family="NanumGothic")
plt.title("배달의 민족 긍정 리뷰 네트워크 시각화")
plt.show()


# 긍정 리뷰2
G = nx.Graph()
ar_p2 = df_apri_p2["items"]
G.add_edges_from(ar_p2)

pr = nx.pagerank(G)
nsize = np.array(list(pr.values()))
nsize = 2000 * (nsize - min(nsize)) / (max(nsize) - min(nsize))

pos = nx.kamada_kawai_layout(G)

nx.draw(G, pos, node_size=nsize, with_labels=True, font_size=10, font_family="NanumGothic")
plt.title("배달의 민족 긍정 리뷰 2 네트워크 시각화")
plt.show()


# 부정 리뷰
G = nx.Graph()
ar_n = df_apri_n["items"]
G.add_edges_from(ar_n)

pr = nx.pagerank(G)
nsize = np.array(list(pr.values()))
nsize = 2000 * (nsize - min(nsize)) / (max(nsize) - min(nsize))

pos = nx.kamada_kawai_layout(G)

nx.draw(G, pos, node_size=nsize, with_labels=True, font_size=10, font_family="NanumGothic")
plt.title("배달의 민족 부정 리뷰 네트워크 시각화")
plt.show()


# 결론:
# 1. 긍정 리뷰의 경우 부정 리뷰에 비해 단어의 연관성이 복잡해보임 -> 긍정적인 점이 여러 개 일 수도 있으나, 그냥 평점을 높게 주는 사람들이 많을 수도 있어 보임
# 2. 부정 리뷰의 경우 주문 및 배달의 빈도가 높음
# 3. 주문 ~ 배달의 경우 긍정 리뷰와 부정 리뷰에서 모두 확인이 가능함 -> 평점을 높이기 위해 주문 ~ 배달에 신경써야 함
# 4. 네트워크 시각화 단계에서 support 점수의 가중치를 추가하는 방안 고려
# 5. 긍정 리뷰1과 긍정 리뷰2를 비교하였을 때, 긍정 리뷰2에서는 (음식, 추가) 및 (추가, 선택) 사이의 간선이 사라짐 -> 음식 추가 선택 관련 부정 리뷰 확인 필요

# %% [markdown]
# #### 댓글별 유사도

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

sentences = [
    "4~5만원 이상을 시켜야만 배달팁이 0원이고 실질적으로 3~6천원까지도 지불해야 하는 가게가 많습니다.",
    "1인 가구 특성상 과도한 배달비는 부담스러울 때가 있어요요",
    "정말로 최고의 배달앱입니다."
]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(sentences)
# print(vectorizer.vocabulary_)
# print(tfidf_matrix.toarray())
# print(tfidf_matrix)

similarity = cosine_similarity(tfidf_matrix)
print(similarity)

# 해석: 전처리가 필요함
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
